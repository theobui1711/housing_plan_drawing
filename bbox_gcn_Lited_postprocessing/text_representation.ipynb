# %%
import json
import os

DATA_DIR = "housing_plan_drawing_data/layout"

# %%
def load_filenames(data_dir, folder='semantic-expression'):
    filenames_ = []
    current_dir_ = os.path.join(data_dir, folder)
    for file in os.listdir(current_dir_):
        filenames_.append(os.path.splitext(file)[0])
    return sorted(filenames_)

# %%
filenames = load_filenames(DATA_DIR)

# %%
current_dir = os.path.join(DATA_DIR, 'semantic-expression')

# %%
path = os.path.join(current_dir, '{}.txt'.format(filenames[0]))
path
# Out:
# 'housing_plan_drawing_data/layout/semantic-expression/00000.txt'

# %%
with open(path, 'r') as f:
    data = json.load(f)

beautiful_json = json.dumps(data, indent=4)
print(beautiful_json)
# Out:
# {
#     "rooms": {
#         "livingroom": {
#             "boundingbox": [
#                 {
#                     "min": {
#                         "x": 168,
#                         "y": 138
#                     },
#                     "max": {
#                         "x": 370,
#                         "y": 371
#                     }
#                 }
#             ],
#             "room num": 1,
#             "name list": [
#                 "livingroom1"
#             ],
#             "size": [
#                 36.38300704956055
#             ],
#             "position": [
#                 "C"
#             ],
#             "furniture assets": [
#                 "FA1"
#             ]
#         },
#         "kitchen": {
#             "boundingbox": [
#                 {
#                     "min": {
#                         "x": 372,
#                         "y": 138
#                     },
#                     "max": {
#                         "x": 432,
#                         "y": 232
#                     }
#                 }
#             ],
#             "room num": 1,
#             "name list": [
#                 "kitchen1"
#             ],
#             "size": [
#                 7.1623992919921875
#             ],
#             "position": [
#                 "NE"
#             ],
#             "furniture assets": [
#                 "FA5"
#             ]
#         },
#         "balcony": {
#             "boundingbox": [
#                 {
#                     "min": {
#                         "x": 168,
#                         "y": 373
#                     },
#                     "max": {
#                         "x": 279,
#                         "y": 420
#                     }
#                 },
#                 {
#                     "min": {
#                         "x": 372,
#                         "y": 92
#                     },
#                     "max": {
#                         "x": 450,
#                         "y": 136
#                     }
#                 }
#             ],
#             "room num": 2,
#             "name list": [
#                 "balcony1",
#                 "balcony2"
#             ],
#             "size": [
#                 6.644530773162842,
#                 4.392608642578125
#             ],
#             "position": [
#                 "S",
#                 "NE"
#             ],
#             "furniture assets": [
#                 "FA6",
#                 "FA8"
#             ]
#         },
#         "bedroom": {
#             "boundingbox": [
#                 {
#                     "min": {
#                         "x": 62,
#                         "y": 234
#                     },
#                     "max": {
#                         "x": 166,
#                         "y": 357
#                     }
#                 },
#                 {
#                     "min": {
#                         "x": 62,
#                         "y": 138
#                     },
#                     "max": {
#                         "x": 166,
#                         "y": 232
#                     }
#                 },
#                 {
#                     "min": {
#                         "x": 206,
#                         "y": 138
#                     },
#                     "max": {
#                         "x": 279,
#                         "y": 232
#                     }
#                 }
#             ],
#             "room num": 3,
#             "name list": [
#                 "bedroom1",
#                 "bedroom2",
#                 "bedroom3"
#             ],
#             "size": [
#                 16.09222412109375,
#                 10.027359008789062,
#                 8.687576293945312
#             ],
#             "position": [
#                 "W",
#                 "NW",
#                 "N"
#             ],
#             "furniture assets": [
#                 "FA2",
#                 "FA3",
#                 "FA4"
#             ]
#         },
#         "washroom": {
#             "boundingbox": [
#                 {
#                     "min": {
#                         "x": 138,
#                         "y": 138
#                     },
#                     "max": {
#                         "x": 204,
#                         "y": 198
#                     }
#                 }
#             ],
#             "room num": 1,
#             "name list": [
#                 "washroom1"
#             ],
#             "size": [
#                 5.050140380859375
#             ],
#             "position": [
#                 "NW"
#             ],
#             "furniture assets": [
#                 "FA7"
#             ]
#         }
#     },
#     "links": [
#         {
#             "door position relative to0": "S",
#             "door position relative to1": "NE",
#             "relative position": "S",
#             "room pair": [
#                 "livingroom1",
#                 "bedroom1"
#             ],
#             "connect type": "OC"
#         },
#         {
#             "door position relative to0": "SE",
#             "door position relative to1": "NW",
#             "relative position": "SE",
#             "room pair": [
#                 "livingroom1",
#                 "bedroom2"
#             ],
#             "connect type": "OC"
#         },
#         {
#             "door position relative to0": "SE",
#             "door position relative to1": "SW",
#             "relative position": "E",
#             "room pair": [
#                 "livingroom1",
#                 "bedroom3"
#             ],
#             "connect type": "OC"
#         },
#         {
#             "door position relative to0": "NE",
#             "door position relative to1": "S",
#             "relative position": "NE",
#             "room pair": [
#                 "livingroom1",
#                 "kitchen1"
#             ],
#             "connect type": "OC"
#         },
#         {
#             "door position relative to0": "W",
#             "door position relative to1": "E",
#             "relative position": "W",
#             "room pair": [
#                 "livingroom1",
#                 "balcony1"
#             ],
#             "connect type": "OC"
#         },
#         {
#             "door position relative to0": "SE",
#             "door position relative to1": "NW",
#             "relative position": "SE",
#             "room pair": [
#                 "livingroom1",
#                 "washroom1"
#             ],
#             "connect type": "OC"
#         },
#         {
#             "relative position": "E",
#             "room pair": [
#                 "bedroom1",
#                 "bedroom2"
#             ],
#             "connect type": "C"
#         },
#         {
#             "relative position": "N",
#             "room pair": [
#                 "bedroom2",
#                 "washroom1"
#             ],
#             "connect type": "C"
#         },
#         {
#             "relative position": "S",
#             "room pair": [
#                 "bedroom3",
#                 "washroom1"
#             ],
#             "connect type": "C"
#         },
#         {
#             "door position relative to0": "E",
#             "door position relative to1": "SW",
#             "relative position": "E",
#             "room pair": [
#                 "kitchen1",
#                 "balcony2"
#             ],
#             "connect type": "OC"
#         }
#     ],
#     "furniture assets": {
#         "FA2": [
#             {
#                 "size": {
#                     "width": 69,
#                     "height": 86
#                 },
#                 "position": "102,306",
#                 "type": "bed"
#             },
#             {
#                 "size": {
#                     "width": 41,
#                     "height": 10
#                 },
#                 "position": "158,306",
#                 "type": "TV stand"
#             }
#         ],
#         "FA1": [
#             {
#                 "size": {
#                     "width": 11,
#                     "height": 51
#                 },
#                 "position": "176,319",
#                 "type": "TV stand"
#             },
#             {
#                 "size": {
#                     "width": 51,
#                     "height": 17
#                 },
#                 "position": "268,321",
#                 "type": "sofa"
#             }
#         ],
#         "FA4": [],
#         "FA3": [
#             {
#                 "size": {
#                     "width": 64,
#                     "height": 63
#                 },
#                 "position": "93,180",
#                 "type": "bed"
#             }
#         ],
#         "FA6": [],
#         "FA5": [],
#         "FA8": [],
#         "FA7": []
#     }
# }

# %%
lin_filenames = load_filenames(DATA_DIR, 'linguistic-expression')
current_dir = os.path.join(DATA_DIR, 'linguistic-expression')
path = os.path.join(current_dir, '{}.txt'.format(lin_filenames[0]))
path
# Out:
# 'housing_plan_drawing_data/layout/linguistic-expression/00000.txt'

# %%
with open(path, 'r') as f:
    data = f.read()

print(data)
# Out:
# The building contains three bedrooms, one washroom, two balconys, one livingroom, and one kitchen. In practice, bedroom1 has 16 squares in west. bedroom1 wall is Gray Coating as well as has Blue Mosaic floor. bedroom2 floor is White Rock_Plate, and wall is Green Quartz. bedroom2 has 10 squares in northwest. Additionally, bedroom3 has Earth_color Painted_Wood floor while wall is Black Wood_Grain. bedroom3 has 9 squares in north. washroom1 is in northwest with 5 square meters. floor of washroom1 is Granite and Wood_color as well as has Yellow Wood_Grain wall. balcony1 wall is Black Log while has Green Painted_Wood floor. balcony1 is in south with 7 square meters. In addition, balcony2 has Yellow Granite floor as well as wall is Wood_Veneer and Blue. balcony2 has 4 squares in northeast. livingroom1 covers 36 square meters located in center. livingroom1 has Black Log wall, and floor is Purple Jade. kitchen1 is in northeast with 7 square meters. kitchen1 floor is Gray Mosaic while wall is Blue Rock_Plate. livingroom1 is adjacent to bedroom1, bedroom2, bedroom3, kitchen1, balcony1, washroom1. bedroom2 and bedroom1 are connected. bedroom2 is next to washroom1. washroom1 and bedroom3 are connected. kitchen1 is next to balcony2.

# %%
sentences = data.split('.')

# %%
import sng_parser

graph = sng_parser.parse(data)

# %%
from pprint import pprint

# %%
for k, v in graph.items():
    print(k)
# Out:
# entities
# relations

# %%
pprint(graph['entities'])
# Out:
# [{'head': 'building',
#   'lemma_head': 'building',
#   'lemma_span': 'the building',
#   'modifiers': [{'dep': 'det', 'lemma_span': 'the', 'span': 'The'}],
#   'span': 'The building',
#   'span_bounds': (0, 2),
#   'type': 'unknown'},
#  {'head': 'bedrooms',
#   'lemma_head': 'bedroom',
#   'lemma_span': 'three bedroom',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': 'three', 'span': 'three'}],
#   'span': 'three bedrooms',
#   'span_bounds': (3, 5),
#   'type': 'scene'},
#  {'head': 'washroom',
#   'lemma_head': 'washroom',
#   'lemma_span': 'one washroom',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': 'one', 'span': 'one'}],
#   'span': 'one washroom',
#   'span_bounds': (6, 8),
#   'type': 'unknown'},
#  {'head': 'balconys',
#   'lemma_head': 'balcony',
#   'lemma_span': 'two balcony',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': 'two', 'span': 'two'}],
#   'span': 'two balconys',
#   'span_bounds': (9, 11),
#   'type': 'scene'},
#  {'head': 'livingroom',
#   'lemma_head': 'livingroom',
#   'lemma_span': 'one livingroom',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': 'one', 'span': 'one'}],
#   'span': 'one livingroom',
#   'span_bounds': (12, 14),
#   'type': 'unknown'},
#  {'head': 'kitchen',
#   'lemma_head': 'kitchen',
#   'lemma_span': 'one kitchen',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': 'one', 'span': 'one'}],
#   'span': 'one kitchen',
#   'span_bounds': (16, 18),
#   'type': 'scene'},
#  {'head': 'practice',
#   'lemma_head': 'practice',
#   'lemma_span': 'practice',
#   'modifiers': [],
#   'span': 'practice',
#   'span_bounds': (20, 21),
#   'type': 'unknown'},
#  {'head': 'bedroom1',
#   'lemma_head': 'bedroom1',
#   'lemma_span': 'bedroom1',
#   'modifiers': [],
#   'span': 'bedroom1',
#   'span_bounds': (22, 23),
#   'type': 'unknown'},
#  {'head': 'squares',
#   'lemma_head': 'square',
#   'lemma_span': '16 square',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': '16', 'span': '16'}],
#   'span': '16 squares',
#   'span_bounds': (24, 26),
#   'type': 'unknown'},
#  {'head': 'west',
#   'lemma_head': 'west',
#   'lemma_span': 'west',
#   'modifiers': [],
#   'span': 'west',
#   'span_bounds': (27, 28),
#   'type': 'unknown'},
#  {'head': 'bedroom1 wall',
#   'lemma_head': 'bedroom1 wall',
#   'lemma_span': 'bedroom1 wall',
#   'modifiers': [],
#   'span': 'bedroom1 wall',
#   'span_bounds': (29, 31),
#   'type': 'unknown'},
#  {'head': 'Gray Coating',
#   'lemma_head': 'Gray Coating',
#   'lemma_span': 'Gray Coating',
#   'modifiers': [],
#   'span': 'Gray Coating',
#   'span_bounds': (32, 34),
#   'type': 'unknown'},
#  {'head': 'Mosaic floor',
#   'lemma_head': 'Mosaic floor',
#   'lemma_span': 'blue Mosaic floor',
#   'modifiers': [],
#   'span': 'Blue Mosaic floor',
#   'span_bounds': (38, 41),
#   'type': 'unknown'},
#  {'head': 'bedroom2 floor',
#   'lemma_head': 'bedroom2 floor',
#   'lemma_span': 'bedroom2 floor',
#   'modifiers': [],
#   'span': 'bedroom2 floor',
#   'span_bounds': (42, 44),
#   'type': 'unknown'},
#  {'head': 'wall',
#   'lemma_head': 'wall',
#   'lemma_span': 'wall',
#   'modifiers': [],
#   'span': 'wall',
#   'span_bounds': (49, 50),
#   'type': 'unknown'},
#  {'head': 'Green Quartz',
#   'lemma_head': 'Green Quartz',
#   'lemma_span': 'Green Quartz',
#   'modifiers': [],
#   'span': 'Green Quartz',
#   'span_bounds': (51, 53),
#   'type': 'unknown'},
#  {'head': 'bedroom2',
#   'lemma_head': 'bedroom2',
#   'lemma_span': 'bedroom2',
#   'modifiers': [],
#   'span': 'bedroom2',
#   'span_bounds': (54, 55),
#   'type': 'unknown'},
#  {'head': 'squares',
#   'lemma_head': 'square',
#   'lemma_span': '10 square',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': '10', 'span': '10'}],
#   'span': '10 squares',
#   'span_bounds': (56, 58),
#   'type': 'unknown'},
#  {'head': 'northwest',
#   'lemma_head': 'northwest',
#   'lemma_span': 'northwest',
#   'modifiers': [],
#   'span': 'northwest',
#   'span_bounds': (59, 60),
#   'type': 'unknown'},
#  {'head': 'bedroom3',
#   'lemma_head': 'bedroom3',
#   'lemma_span': 'bedroom3',
#   'modifiers': [],
#   'span': 'bedroom3',
#   'span_bounds': (63, 64),
#   'type': 'unknown'},
#  {'head': 'Painted_Wood floor',
#   'lemma_head': 'painted_wood floor',
#   'lemma_span': 'earth_color painted_wood floor',
#   'modifiers': [],
#   'span': 'Earth_color Painted_Wood floor',
#   'span_bounds': (65, 68),
#   'type': 'unknown'},
#  {'head': 'wall',
#   'lemma_head': 'wall',
#   'lemma_span': 'wall',
#   'modifiers': [],
#   'span': 'wall',
#   'span_bounds': (69, 70),
#   'type': 'unknown'},
#  {'head': 'Black Wood_Grain',
#   'lemma_head': 'Black Wood_Grain',
#   'lemma_span': 'Black Wood_Grain',
#   'modifiers': [],
#   'span': 'Black Wood_Grain',
#   'span_bounds': (71, 73),
#   'type': 'unknown'},
#  {'head': 'bedroom3',
#   'lemma_head': 'bedroom3',
#   'lemma_span': 'bedroom3',
#   'modifiers': [],
#   'span': 'bedroom3',
#   'span_bounds': (74, 75),
#   'type': 'unknown'},
#  {'head': 'squares',
#   'lemma_head': 'square',
#   'lemma_span': '9 square',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': '9', 'span': '9'}],
#   'span': '9 squares',
#   'span_bounds': (76, 78),
#   'type': 'unknown'},
#  {'head': 'north',
#   'lemma_head': 'north',
#   'lemma_span': 'north',
#   'modifiers': [],
#   'span': 'north',
#   'span_bounds': (79, 80),
#   'type': 'unknown'},
#  {'head': 'washroom1',
#   'lemma_head': 'washroom1',
#   'lemma_span': 'washroom1',
#   'modifiers': [],
#   'span': 'washroom1',
#   'span_bounds': (81, 82),
#   'type': 'unknown'},
#  {'head': 'northwest',
#   'lemma_head': 'northwest',
#   'lemma_span': 'northwest',
#   'modifiers': [],
#   'span': 'northwest',
#   'span_bounds': (84, 85),
#   'type': 'unknown'},
#  {'head': 'meters',
#   'lemma_head': 'meter',
#   'lemma_span': '5 square meter',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': '5', 'span': '5'},
#                 {'dep': 'amod', 'lemma_span': 'square', 'span': 'square'}],
#   'span': '5 square meters',
#   'span_bounds': (86, 89),
#   'type': 'unknown'},
#  {'head': 'floor',
#   'lemma_head': 'floor',
#   'lemma_span': 'floor',
#   'modifiers': [],
#   'span': 'floor',
#   'span_bounds': (90, 91),
#   'type': 'unknown'},
#  {'head': 'washroom1',
#   'lemma_head': 'washroom1',
#   'lemma_span': 'washroom1',
#   'modifiers': [],
#   'span': 'washroom1',
#   'span_bounds': (92, 93),
#   'type': 'unknown'},
#  {'head': 'Granite',
#   'lemma_head': 'Granite',
#   'lemma_span': 'Granite',
#   'modifiers': [],
#   'span': 'Granite',
#   'span_bounds': (94, 95),
#   'type': 'unknown'},
#  {'head': 'Wood_Grain Yellow wall',
#   'lemma_head': 'Wood_Grain Yellow wall',
#   'lemma_span': 'Yellow Wood_Grain wall',
#   'modifiers': [],
#   'span': 'Yellow Wood_Grain wall',
#   'span_bounds': (101, 104),
#   'type': 'unknown'},
#  {'head': 'balcony1 wall',
#   'lemma_head': 'balcony1 wall',
#   'lemma_span': 'balcony1 wall',
#   'modifiers': [],
#   'span': 'balcony1 wall',
#   'span_bounds': (105, 107),
#   'type': 'unknown'},
#  {'head': 'Black Log',
#   'lemma_head': 'Black Log',
#   'lemma_span': 'Black Log',
#   'modifiers': [],
#   'span': 'Black Log',
#   'span_bounds': (108, 110),
#   'type': 'unknown'},
#  {'head': 'Painted_Wood Green floor',
#   'lemma_head': 'Painted_Wood Green floor',
#   'lemma_span': 'Green Painted_Wood floor',
#   'modifiers': [],
#   'span': 'Green Painted_Wood floor',
#   'span_bounds': (112, 115),
#   'type': 'unknown'},
#  {'head': 'balcony1',
#   'lemma_head': 'balcony1',
#   'lemma_span': 'balcony1',
#   'modifiers': [],
#   'span': 'balcony1',
#   'span_bounds': (116, 117),
#   'type': 'unknown'},
#  {'head': 'south',
#   'lemma_head': 'south',
#   'lemma_span': 'south',
#   'modifiers': [],
#   'span': 'south',
#   'span_bounds': (119, 120),
#   'type': 'unknown'},
#  {'head': 'meters',
#   'lemma_head': 'meter',
#   'lemma_span': '7 square meter',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': '7', 'span': '7'},
#                 {'dep': 'amod', 'lemma_span': 'square', 'span': 'square'}],
#   'span': '7 square meters',
#   'span_bounds': (121, 124),
#   'type': 'unknown'},
#  {'head': 'addition',
#   'lemma_head': 'addition',
#   'lemma_span': 'addition',
#   'modifiers': [],
#   'span': 'addition',
#   'span_bounds': (126, 127),
#   'type': 'unknown'},
#  {'head': 'balcony2',
#   'lemma_head': 'balcony2',
#   'lemma_span': 'balcony2',
#   'modifiers': [],
#   'span': 'balcony2',
#   'span_bounds': (128, 129),
#   'type': 'unknown'},
#  {'head': 'Granite floor',
#   'lemma_head': 'Granite floor',
#   'lemma_span': 'Yellow Granite floor',
#   'modifiers': [],
#   'span': 'Yellow Granite floor',
#   'span_bounds': (130, 133),
#   'type': 'unknown'},
#  {'head': 'wall',
#   'lemma_head': 'wall',
#   'lemma_span': 'wall',
#   'modifiers': [],
#   'span': 'wall',
#   'span_bounds': (136, 137),
#   'type': 'unknown'},
#  {'head': 'Blue',
#   'lemma_head': 'Blue',
#   'lemma_span': 'Blue',
#   'modifiers': [],
#   'span': 'Blue',
#   'span_bounds': (140, 141),
#   'type': 'unknown'},
#  {'head': 'balcony2',
#   'lemma_head': 'balcony2',
#   'lemma_span': 'balcony2',
#   'modifiers': [],
#   'span': 'balcony2',
#   'span_bounds': (142, 143),
#   'type': 'unknown'},
#  {'head': 'squares',
#   'lemma_head': 'square',
#   'lemma_span': '4 square',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': '4', 'span': '4'}],
#   'span': '4 squares',
#   'span_bounds': (144, 146),
#   'type': 'unknown'},
#  {'head': 'northeast',
#   'lemma_head': 'northeast',
#   'lemma_span': 'northeast',
#   'modifiers': [],
#   'span': 'northeast',
#   'span_bounds': (147, 148),
#   'type': 'unknown'},
#  {'head': 'livingroom1',
#   'lemma_head': 'livingroom1',
#   'lemma_span': 'livingroom1',
#   'modifiers': [],
#   'span': 'livingroom1',
#   'span_bounds': (149, 150),
#   'type': 'unknown'},
#  {'head': 'meters',
#   'lemma_head': 'meter',
#   'lemma_span': '36 square meter',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': '36', 'span': '36'},
#                 {'dep': 'amod', 'lemma_span': 'square', 'span': 'square'}],
#   'span': '36 square meters',
#   'span_bounds': (151, 154),
#   'type': 'unknown'},
#  {'head': 'center',
#   'lemma_head': 'center',
#   'lemma_span': 'center',
#   'modifiers': [],
#   'span': 'center',
#   'span_bounds': (156, 157),
#   'type': 'unknown'},
#  {'head': 'livingroom1',
#   'lemma_head': 'livingroom1',
#   'lemma_span': 'livingroom1',
#   'modifiers': [],
#   'span': 'livingroom1',
#   'span_bounds': (158, 159),
#   'type': 'unknown'},
#  {'head': 'Log wall',
#   'lemma_head': 'Log wall',
#   'lemma_span': 'Black Log wall',
#   'modifiers': [],
#   'span': 'Black Log wall',
#   'span_bounds': (160, 163),
#   'type': 'unknown'},
#  {'head': 'floor',
#   'lemma_head': 'floor',
#   'lemma_span': 'floor',
#   'modifiers': [],
#   'span': 'floor',
#   'span_bounds': (165, 166),
#   'type': 'unknown'},
#  {'head': 'Purple Jade',
#   'lemma_head': 'Purple Jade',
#   'lemma_span': 'Purple Jade',
#   'modifiers': [],
#   'span': 'Purple Jade',
#   'span_bounds': (167, 169),
#   'type': 'unknown'},
#  {'head': 'kitchen1',
#   'lemma_head': 'kitchen1',
#   'lemma_span': 'kitchen1',
#   'modifiers': [],
#   'span': 'kitchen1',
#   'span_bounds': (170, 171),
#   'type': 'unknown'},
#  {'head': 'meters',
#   'lemma_head': 'meter',
#   'lemma_span': '7 square meter',
#   'modifiers': [{'dep': 'nummod', 'lemma_span': '7', 'span': '7'},
#                 {'dep': 'amod', 'lemma_span': 'square', 'span': 'square'}],
#   'span': '7 square meters',
#   'span_bounds': (175, 178),
#   'type': 'unknown'},
#  {'head': 'kitchen1 floor',
#   'lemma_head': 'kitchen1 floor',
#   'lemma_span': 'kitchen1 floor',
#   'modifiers': [],
#   'span': 'kitchen1 floor',
#   'span_bounds': (179, 181),
#   'type': 'unknown'},
#  {'head': 'Gray Mosaic',
#   'lemma_head': 'Gray Mosaic',
#   'lemma_span': 'Gray Mosaic',
#   'modifiers': [],
#   'span': 'Gray Mosaic',
#   'span_bounds': (182, 184),
#   'type': 'unknown'},
#  {'head': 'wall',
#   'lemma_head': 'wall',
#   'lemma_span': 'wall',
#   'modifiers': [],
#   'span': 'wall',
#   'span_bounds': (185, 186),
#   'type': 'unknown'},
#  {'head': 'Rock_Plate',
#   'lemma_head': 'rock_plate',
#   'lemma_span': 'blue rock_plate',
#   'modifiers': [{'dep': 'amod', 'lemma_span': 'blue', 'span': 'Blue'}],
#   'span': 'Blue Rock_Plate',
#   'span_bounds': (187, 189),
#   'type': 'unknown'},
#  {'head': 'livingroom1',
#   'lemma_head': 'livingroom1',
#   'lemma_span': 'livingroom1',
#   'modifiers': [],
#   'span': 'livingroom1',
#   'span_bounds': (190, 191),
#   'type': 'unknown'},
#  {'head': 'bedroom1',
#   'lemma_head': 'bedroom1',
#   'lemma_span': 'bedroom1',
#   'modifiers': [],
#   'span': 'bedroom1',
#   'span_bounds': (194, 195),
#   'type': 'unknown'},
#  {'head': 'bedroom2',
#   'lemma_head': 'bedroom2',
#   'lemma_span': 'bedroom2',
#   'modifiers': [],
#   'span': 'bedroom2',
#   'span_bounds': (196, 197),
#   'type': 'unknown'},
#  {'head': 'bedroom3',
#   'lemma_head': 'bedroom3',
#   'lemma_span': 'bedroom3',
#   'modifiers': [],
#   'span': 'bedroom3',
#   'span_bounds': (198, 199),
#   'type': 'unknown'},
#  {'head': 'kitchen1',
#   'lemma_head': 'kitchen1',
#   'lemma_span': 'kitchen1',
#   'modifiers': [],
#   'span': 'kitchen1',
#   'span_bounds': (200, 201),
#   'type': 'unknown'},
#  {'head': 'balcony1',
#   'lemma_head': 'balcony1',
#   'lemma_span': 'balcony1',
#   'modifiers': [],
#   'span': 'balcony1',
#   'span_bounds': (202, 203),
#   'type': 'unknown'},
#  {'head': 'washroom1',
#   'lemma_head': 'washroom1',
#   'lemma_span': 'washroom1',
#   'modifiers': [],
#   'span': 'washroom1',
#   'span_bounds': (204, 205),
#   'type': 'unknown'},
#  {'head': 'bedroom2',
#   'lemma_head': 'bedroom2',
#   'lemma_span': 'bedroom2',
#   'modifiers': [],
#   'span': 'bedroom2',
#   'span_bounds': (206, 207),
#   'type': 'unknown'},
#  {'head': 'bedroom1',
#   'lemma_head': 'bedroom1',
#   'lemma_span': 'bedroom1',
#   'modifiers': [],
#   'span': 'bedroom1',
#   'span_bounds': (208, 209),
#   'type': 'unknown'},
#  {'head': 'bedroom2',
#   'lemma_head': 'bedroom2',
#   'lemma_span': 'bedroom2',
#   'modifiers': [],
#   'span': 'bedroom2',
#   'span_bounds': (212, 213),
#   'type': 'unknown'},
#  {'head': 'washroom1',
#   'lemma_head': 'washroom1',
#   'lemma_span': 'washroom1',
#   'modifiers': [],
#   'span': 'washroom1',
#   'span_bounds': (216, 217),
#   'type': 'unknown'},
#  {'head': 'washroom1',
#   'lemma_head': 'washroom1',
#   'lemma_span': 'washroom1',
#   'modifiers': [],
#   'span': 'washroom1',
#   'span_bounds': (218, 219),
#   'type': 'unknown'},
#  {'head': 'bedroom3',
#   'lemma_head': 'bedroom3',
#   'lemma_span': 'bedroom3',
#   'modifiers': [],
#   'span': 'bedroom3',
#   'span_bounds': (220, 221),
#   'type': 'unknown'},
#  {'head': 'kitchen1',
#   'lemma_head': 'kitchen1',
#   'lemma_span': 'kitchen1',
#   'modifiers': [],
#   'span': 'kitchen1',
#   'span_bounds': (224, 225),
#   'type': 'unknown'},
#  {'head': 'balcony2',
#   'lemma_head': 'balcony2',
#   'lemma_span': 'balcony2',
#   'modifiers': [],
#   'span': 'balcony2',
#   'span_bounds': (228, 229),
#   'type': 'unknown'}]

# %%
def parse_room_num(text):
    num_dict = {"one": 1, "two": 2, "three": 3, "four": 4, "five": 5,
                "six": 6, "seven": 7, "eight": 8, "nine": 9, "ten": 10}
    room_num_ = 0
    text = text.lower()
    for work in text.split():
        if work in num_dict:
            room_num_ = num_dict[work]
    return room_num_

# %%
rooms = {}
room_types = ["livingroom", "kitchen", "balcony", "bedroom", "washroom"]
properties = {
    "room num": 0,
    "name list": set(),
    "size": list(),
    "position": list(),
    "furniture assets": set(),
    "boundingbox": set(),
}

for room_type in room_types:
    rooms[room_type] = properties.copy()

# %%
for entity in graph['entities']:
    for room in rooms:
        if room in entity['lemma_head']:
            if entity['lemma_span'] != entity['lemma_head']:
                rooms[room]['room num'] = parse_room_num(entity['lemma_span'])
                rooms[room]['name list'] = [f"{room}{str(i + 1)}" for i in range(rooms[room]['room num'])]

pprint(rooms)
# Out:
# {'balcony': {'boundingbox': set(),
#              'furniture assets': set(),
#              'name list': ['balcony1', 'balcony2'],
#              'position': [],
#              'room num': 2,
#              'size': []},
#  'bedroom': {'boundingbox': set(),
#              'furniture assets': set(),
#              'name list': ['bedroom1', 'bedroom2', 'bedroom3'],
#              'position': [],
#              'room num': 3,
#              'size': []},
#  'kitchen': {'boundingbox': set(),
#              'furniture assets': set(),
#              'name list': ['kitchen1'],
#              'position': [],
#              'room num': 1,
#              'size': []},
#  'livingroom': {'boundingbox': set(),
#                 'furniture assets': set(),
#                 'name list': ['livingroom1'],
#                 'position': [],
#                 'room num': 1,
#                 'size': []},
#  'washroom': {'boundingbox': set(),
#               'furniture assets': set(),
#               'name list': ['washroom1'],
#               'position': [],
#               'room num': 1,
#               'size': []}}

# %%
def parse_room_size(room_):
    room_size = []
    for name in rooms[room_]['name list']:
        for sentence in sentences:
            if name in sentence:
                graph_ = sng_parser.parse(sentence)
                for entity_ in graph_['entities']:
                    if "square" in entity_['lemma_span']:
                        # print(entity)
                        size = int(entity_['lemma_span'].split()[0])
                        room_size.append(size)
    return room_size

# %%
for room in rooms:
    rooms[room]['size'] = parse_room_size(room)

# %%
position_words_dict = {
    "center": "C",
    "north": "N",
    "northeast": "NE", # northeast
    "west": "W",
    "northwest": "NW",
    "east": "E",
    "southwest": "SW",
    "south": "S",
    "southeast": "SE"
}

# %%
def parse_room_position(room_):
    room_position = set()
    for name in rooms[room_]['name list']:
        for sentence in sentences:
            if name in sentence:
                graph_ = sng_parser.parse(sentence)
                for entity_ in graph_['entities']:
                    if entity_['span'] in position_words_dict:
                        room_position.add(position_words_dict[entity_['span']])
    return room_position

# %%
def parse_room_position_2(room_):
    room_position = set()
    for name in rooms[room_]['name list']:
        for sentence in sentences:
            if name in sentence:
                for word in sentence.split():
                    if word in position_words_dict:
                        room_position.add(position_words_dict[word])
    return room_position

# %%
for room in rooms:
    rooms[room]['position'] = parse_room_position_2(room)

# %%
pprint(rooms)
# Out:
# {'balcony': {'boundingbox': set(),
#              'furniture assets': set(),
#              'name list': ['balcony1', 'balcony2'],
#              'position': {'NE', 'S'},
#              'room num': 2,
#              'size': [7, 4]},
#  'bedroom': {'boundingbox': set(),
#              'furniture assets': set(),
#              'name list': ['bedroom1', 'bedroom2', 'bedroom3'],
#              'position': {'W', 'N', 'NW'},
#              'room num': 3,
#              'size': [16, 10, 9]},
#  'kitchen': {'boundingbox': set(),
#              'furniture assets': set(),
#              'name list': ['kitchen1'],
#              'position': {'NE'},
#              'room num': 1,
#              'size': [7]},
#  'livingroom': {'boundingbox': set(),
#                 'furniture assets': set(),
#                 'name list': ['livingroom1'],
#                 'position': {'C'},
#                 'room num': 1,
#                 'size': [36]},
#  'washroom': {'boundingbox': set(),
#               'furniture assets': set(),
#               'name list': ['washroom1'],
#               'position': {'NW'},
#               'room num': 1,
#               'size': [5]}}

# %%
def generate_bounding_box(room_, canvas_size=512, real_world_size=18):
    scale_factor = canvas_size / real_world_size

    bbox_list = []

    for i in range(room_['room num']):
        size = room_['size'][i]
        position = list(room_['position'])[i]

        # Define what each position means in terms of coordinates
        position_dict = {
            "C": (0, 0),
            "N": (0, size),
            "NE": (size, size),
            "E": (size, 0),
            "SE": (size, -size),
            "S": (0, -size),
            "SW": (-size, -size),
            "W": (-size, 0),
            "NW": (-size, size)
        }

        # Calculate the coordinates of the bounding box
        center_x, center_y = position_dict[position]
        min_x = center_x - size / 2
        max_x = center_x + size / 2
        min_y = center_y - size / 2
        max_y = center_y + size / 2

        bbox_list.append({
            "min": {"x": min_x, "y": min_y},
            "max": {"x": max_x, "y": max_y}
        })
    room_['boundingbox'] = bbox_list
    return room_

# %%
for room in rooms:
    pprint(generate_bounding_box(rooms[room]))
# Out:
# {'boundingbox': [{'max': {'x': 512.0, 'y': 512.0},
#                   'min': {'x': -512.0, 'y': -512.0}}],
#  'furniture assets': set(),
#  'name list': ['livingroom1'],
#  'position': {'C'},
#  'room num': 1,
#  'size': [36]}
# {'boundingbox': [{'max': {'x': 298.66666666666663, 'y': 298.66666666666663},
#                   'min': {'x': 99.55555555555554, 'y': 99.55555555555554}}],
#  'furniture assets': set(),
#  'name list': ['kitchen1'],
#  'position': {'NE'},
#  'room num': 1,
#  'size': [7]}
# {'boundingbox': [{'max': {'x': 298.66666666666663, 'y': 298.66666666666663},
#                   'min': {'x': 99.55555555555554, 'y': 99.55555555555554}},
#                  {'max': {'x': 56.888888888888886, 'y': -56.888888888888886},
#                   'min': {'x': -56.888888888888886, 'y': -170.66666666666666}}],
#  'furniture assets': set(),
#  'name list': ['balcony1', 'balcony2'],
#  'position': {'NE', 'S'},
#  'room num': 2,
#  'size': [7, 4]}
# {'boundingbox': [{'max': {'x': -227.55555555555554, 'y': 227.55555555555554},
#                   'min': {'x': -682.6666666666666, 'y': -227.55555555555554}},
#                  {'max': {'x': 142.22222222222223, 'y': 426.66666666666663},
#                   'min': {'x': -142.22222222222223, 'y': 142.22222222222223}},
#                  {'max': {'x': -128.0, 'y': 384.0},
#                   'min': {'x': -384.0, 'y': 128.0}}],
#  'furniture assets': set(),
#  'name list': ['bedroom1', 'bedroom2', 'bedroom3'],
#  'position': {'W', 'N', 'NW'},
#  'room num': 3,
#  'size': [16, 10, 9]}
# {'boundingbox': [{'max': {'x': -71.11111111111111, 'y': 213.33333333333331},
#                   'min': {'x': -213.33333333333331, 'y': 71.11111111111111}}],
#  'furniture assets': set(),
#  'name list': ['washroom1'],
#  'position': {'NW'},
#  'room num': 1,
#  'size': [5]}
